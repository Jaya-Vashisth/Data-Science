# %%
# !pip install scrapy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#                                               0.0/277.2 kB ? eta -:--:--
#      ----                                     30.7/277.2 kB ? eta -:--:--
#      ----                                     30.7/277.2 kB ? eta -:--:--
#      ----                                     30.7/277.2 kB ? eta -:--:--
#      ----                                     30.7/277.2 kB ? eta -:--:--
#      ----                                     30.7/277.2 kB ? eta -:--:--
#      ------------                          92.2/277.2 kB 350.1 kB/s eta 0:00:01
#      ---------------                      122.9/277.2 kB 361.0 kB/s eta 0:00:01
#      ------------------                   143.4/277.2 kB 405.9 kB/s eta 0:00:01
#      ------------------                   143.4/277.2 kB 405.9 kB/s eta 0:00:01
#      ------------------                   143.4/277.2 kB 405.9 kB/s eta 0:00:01
# ...

# %%
# !scrapy startproject myproject
# Out:
# 'scrapy' is not recognized as an internal or external command,
# operable program or batch file.
